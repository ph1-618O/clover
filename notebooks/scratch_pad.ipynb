# %%
import pprint
pp = pprint.PrettyPrinter(indent=4)

# %%
dict = {   '0_format': [   'date',
                    'location data',
                    'float amount',
                    'identifier',
                    'category'],
    'debt': [],
    'deposits': [],
    'fast_food': [   [   '01/28/21',
                         'CHICK-FIL-A',
                         -14.99,
                         'CHICK-FIL-A',
                         'fast_food'],
                     [   '03/15/21',
                         'BOJANGLES 5555 ELIZABETH CITY NY',
                         -12.99,
                         'BOJANGLES',
                         'fast_food']],
    'food': [   ['01/22/21', 'FOOD LION', -200, 'FOOD LION', 'food'],
                ['02/21/21', 'HARRIS_TEETER', -250, 'HARRIS', 'food'],
                ['03/15/21', 'FARM_FRESH', -150, 'FRESH', 'food'],
                [   '04/15/2021',
                    'FOOD LION #8457 CHINA LAKE CA',
                    '-$69.99',
                    'lion',
                    'food']],
    'fun': [],
    'gas': [   [   '03/22/21',
                   'SHELL OIL 2423423423423 LUCY, PA',
                   -28,
                   'SHELL',
                   'gas'],
               [   '04/19/2021',
                   'SHELL OIL 45468787999 BOSTON, MA',
                   '-$8.46',
                   'shell',
                   'gas'],
               [   '04/19/2021',
                   'MAPCO 1571 FLOWER, FL',
                   '-$7.67',
                   'mapco',
                   'gas'],
               [   '04/22/2021',
                   'MAPCO 1571 FLOWER, FL',
                   '-$8.67',
                   'mapco',
                   'gas']],
    'home': [   ['01/24/21', 'HOME_DEPOT', -57, 'DEPOT', 'home'],
                ['01/12/21', 'LOWES', -100, 'LOWES', 'home'],
                ['02/14/21', 'TRUE_VALUE', -60, 'TRUE', 'home']],
    'income': [],
    'interest': [],
    'medical': [   [   '05/16/2021',
                       'PHYSICIANS OFFICE 888-666-2424 AL',
                       '-$49.95',
                       'physicians',
                       'medical'],
                   [   '05/13/2021',
                       'PHYSICIANS OFFICE 888-666-2424 AL',
                       '-$100.95',
                       'physicians',
                       'medical'],
                   [   '04/14/2021',
                       'RITE AID 1574 LITTLE ROCK AK',
                       '-$5.09',
                       'rite',
                       'medical']],
    'online': [   [   '04/15/2021',
                      'PAYPAL *PURCHASE 555-634-1921 CA',
                      '-$39.99',
                      'paypal',
                      'online'],
                  [   '04/15/2021',
                      'PAYPAL *PURCHASE 555-634-1921 CA',
                      '-$39.99',
                      'paypal',
                      'online'],
                  [   '04/14/2021',
                      'AMZN Mktp US*FB12334 Amzn.com/billWA',
                      '-$23.45',
                      'amzn',
                      'online']],
    'pets': [],
    'restaurants': [],
    'savings': [],
    'transportation': [],
    'utilities': [   [   '03/18/21',
                         'DENVER SANITATION 489-4698-06456 CO',
                         -80,
                         'SANITATION',
                         'utilities']]}

# %%
for i in dict.keys():
    pp.pprint(f'{dict[i]}')
    print('')
# Out:
# "['date', 'location data', 'float amount', 'identifier', 'category']"
#
# '[]'
#
# '[]'
#
# ("[['01/28/21', 'CHICK-FIL-A', -14.99, 'CHICK-FIL-A', 'fast_food'], "
#  "['03/15/21', 'BOJANGLES 5555 ELIZABETH CITY NY', -12.99, 'BOJANGLES', "
#  "'fast_food']]")
#
# ("[['01/22/21', 'FOOD LION', -200, 'FOOD LION', 'food'], ['02/21/21', "
#  "'HARRIS_TEETER', -250, 'HARRIS', 'food'], ['03/15/21', 'FARM_FRESH', -150, "
#  "'FRESH', 'food'], ['04/15/2021', 'FOOD LION #8457 CHINA LAKE CA', '-$69.99', "
#  "'lion', 'food']]")
#
# '[]'
#
# ("[['03/22/21', 'SHELL OIL 2423423423423 LUCY, PA', -28, 'SHELL', 'gas'], "
#  "['04/19/2021', 'SHELL OIL 45468787999 BOSTON, MA', '-$8.46', 'shell', "
#  "'gas'], ['04/19/2021', 'MAPCO 1571 FLOWER, FL', '-$7.67', 'mapco', 'gas'], "
#  "['04/22/2021', 'MAPCO 1571 FLOWER, FL', '-$8.67', 'mapco', 'gas']]")
#
# ("[['01/24/21', 'HOME_DEPOT', -57, 'DEPOT', 'home'], ['01/12/21', 'LOWES', "
# ...

# %%
h
